# %%
from data import *
from train import *
from test import *
from model import *
from params import *


trainGenerator,valGenerator,testGenerator=create_generators()


model=training(trainGenerator,valGenerator,descenteGrade)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-0db93f323b3b> in <module>
# ----> 1 from data import *
#       2 from train import *
#       3 from test import *
#       4 from model import *
#       5 from params import *
#
# /work/data.py in <module>
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import keras
#       5 from keras.preprocessing.image import load_img, smart_resize
#       6 from params import *
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/keras/__init__.py in <module>
#       1
#       2 try:
# ----> 3     from tensorflow.keras.layers.experimental.preprocessing import RandomRotation
#       4 except ImportError:
#       5     raise ImportError(
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/tensorflow/__init__.py in <module>
#      39 import sys as _sys
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      43
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/tensorflow/python/__init__.py in <module>
#      44
#      45 # Bring in subpackages.
# ---> 46 from tensorflow.python import data
#      47 from tensorflow.python import distribute
#      48 from tensorflow.python import keras
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/tensorflow/python/data/__init__.py in <module>
#      23
#      24 # pylint: disable=unused-import
# ---> 25 from tensorflow.python.data import experimental
#      26 from tensorflow.python.data.ops.dataset_ops import AUTOTUNE
#      27 from tensorflow.python.data.ops.dataset_ops import Dataset
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/tensorflow/python/data/experimental/__init__.py in <module>
#      94
#      95 # pylint: disable=unused-import
# ---> 96 from tensorflow.python.data.experimental import service
#      97 from tensorflow.python.data.experimental.ops.batching import dense_to_ragged_batch
#      98 from tensorflow.python.data.experimental.ops.batching import dense_to_sparse_batch
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/tensorflow/python/data/experimental/service/__init__.py in <module>
#     138 from __future__ import print_function
#     139
# --> 140 from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#     141 from tensorflow.python.data.experimental.ops.data_service_ops import from_dataset_id
#     142 from tensorflow.python.data.experimental.ops.data_service_ops import register_dataset
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/tensorflow/python/data/experimental/ops/data_service_ops.py in <module>
#      26 from tensorflow.python.data.experimental.ops.distribute_options import AutoShardPolicy
#      27 from tensorflow.python.data.experimental.ops.distribute_options import ExternalStatePolicy
# ---> 28 from tensorflow.python.data.ops import dataset_ops
#      29 from tensorflow.python.framework import dtypes
#      30 from tensorflow.python.framework import ops
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py in <module>
#      33 from tensorflow.python.data.experimental.ops import distribute_options
#      34 from tensorflow.python.data.experimental.ops import optimization_options
# ---> 35 from tensorflow.python.data.experimental.ops import stats_options
#      36 from tensorflow.python.data.experimental.ops import threading_options
#      37 from tensorflow.python.data.ops import iterator_ops
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/tensorflow/python/data/experimental/ops/stats_options.py in <module>
#      20 from __future__ import print_function
#      21
# ---> 22 from tensorflow.python.data.experimental.ops import stats_aggregator
#      23 from tensorflow.python.data.util import options
#      24 from tensorflow.python.util.tf_export import tf_export
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/tensorflow/python/data/experimental/ops/stats_aggregator.py in <module>
#      21
#      22 from tensorflow.python.ops import gen_experimental_dataset_ops as ged_ops
# ---> 23 from tensorflow.python.ops import summary_ops_v2
#      24 from tensorflow.python.util import deprecation
#      25 from tensorflow.python.util.tf_export import tf_export
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/tensorflow/python/ops/summary_ops_v2.py in <module>
#      35 from tensorflow.core.protobuf import config_pb2
#      36 from tensorflow.python.eager import context
# ---> 37 from tensorflow.python.eager import profiler as _profiler
#      38 from tensorflow.python.framework import constant_op
#      39 from tensorflow.python.framework import dtypes
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/tensorflow/python/eager/profiler.py in <module>
#      42 from tensorflow.python.eager import context
#      43 from tensorflow.python.framework import errors
# ---> 44 from tensorflow.python.platform import gfile
#      45 from tensorflow.python.platform import tf_logging as logging
#      46 from tensorflow.python.profiler.internal import _pywrap_profiler
#
# /usr/local/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/local/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/local/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/local/lib/python3.7/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/local/lib/python3.7/importlib/_bootstrap_external.py in get_code(self, fullname)
#
# /usr/local/lib/python3.7/importlib/_bootstrap_external.py in get_data(self, path)
#
# KeyboardInterrupt:

# %%
trainGenerator.__da
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-63765d998dde> in <module>
# ----> 1 trainGenerator.__data_generation
#
# AttributeError: 'DataGeneratorClassifier' object has no attribute '__data_generation'

# %% [markdown]
# data : data_split
# déterminer la taille de la base de données de test (Alexandre)
#
# main
# - entraînement
# - validation
# - test
# - cross validation (à la fin)
#
# model (construire un CNN, activation en sortie = softmax, activation = sigmoid) (Pierre)
#
# train (loss = crossentropy, nb epochs dans params, taux d'apprentissage) (Alexandre)
#
# codage métrique dans utils
# codage matrice de confusion dans utils
#
# test (affiche la loss, la métrique et la matrice de confusion)

# %%
trainGenerator,valGenerator,testGenerator=create_generators()


model=training(trainGenerator,valGenerator,descenteGrade)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-592320676aa4> in <module>
#       2
#       3
# ----> 4 model=training(trainGenerator,valGenerator,descenteGrade)
#
# NameError: name 'training' is not defined

# %%
! python train.py
# Out:
# 2021-02-11 15:42:46.349516: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-02-11 15:42:46.349560: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2021-02-11 15:43:50.008600: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-11 15:43:50.012829: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-02-11 15:43:50.012888: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-02-11 15:43:50.012926: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (p-7b18b6fc-33c1-4d19-8af7-1afafc108f4a): /proc/driver/nvidia/version does not exist
# 2021-02-11 15:43:50.013427: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-02-11 15:43:50.013968: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# dropout (Dropout)            (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                262208
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 390
# =================================================================
# Total params: 355,846
# Trainable params: 355,846
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# dropout (Dropout)            (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                262208
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 390
# =================================================================
# Total params: 355,846
# Trainable params: 355,846
# Non-trainable params: 0
# _________________________________________________________________

# %%
# !git remote add origin https://github.com/VincentH23/ProjetClassificationDechet1.git

# %%
! git add .

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7b18b6fc-33c1-4d19-8af7-1afafc108f4a' target="_blank">
# <img style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
