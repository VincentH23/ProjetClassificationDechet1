# %%
from data import *
from train import *
from test import *
from model import *
from params import *

trainGenerator,valGenerator,testGenerator=create_generators()


model,history=training(trainGenerator,valGenerator,descenteGrade)
# Out:
# sa4
#
#
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# depthwise_conv2d_5 (Depthwis (None, 128, 128, 3)       30
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 128, 128, 64)      256
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# depthwise_conv2d_6 (Depthwis (None, 64, 64, 64)        640
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 64, 64, 128)       8320
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 32, 32, 128)       0
# _________________________________________________________________
# depthwise_conv2d_7 (Depthwis (None, 32, 32, 128)       1280
# ...

# %%
test(valGenerator, model)
# Out:
# 1/1 [==============================] - 7s 7s/step - loss: 1.7822 - accuracy: 0.2346 - workforce: 25.0000
# Nombre d'opérateurs nécessaires par ligne (base de données de test)
# [0.0, 0.0, 0.0, 0.0, 24.015978564443095, 0.0]
# [1.7821805477142334, 0.23456789553165436, 25.0]

# %% [markdown]
# data : data_split
# déterminer la taille de la base de données de test (Alexandre)
#
# main
# - entraînement
# - validation
# - test
# - cross validation (à la fin)
#
# model (construire un CNN, activation en sortie = softmax, activation = sigmoid) (Pierre)
#
# train (loss = crossentropy, nb epochs dans params, taux d'apprentissage) (Alexandre)
#
# codage métrique dans utils
# codage matrice de confusion dans utils
#
# test (affiche la loss, la métrique et la matrice de confusion)

# %%
trainGenerator,valGenerator,testGenerator=create_generators()


model=training(trainGenerator,valGenerator,descenteGrade)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-592320676aa4> in <module>
#       2
#       3
# ----> 4 model=training(trainGenerator,valGenerator,descenteGrade)
#
# NameError: name 'training' is not defined

# %%
! python train.py
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# depthwise_conv2d_30 (Depthwi (None, 128, 128, 3)       30
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 128, 128, 64)      256
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 64, 64, 64)        0
# _________________________________________________________________
# depthwise_conv2d_31 (Depthwi (None, 64, 64, 64)        640
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 64, 64, 128)       8320
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 32, 32, 128)       0
# _________________________________________________________________
# depthwise_conv2d_32 (Depthwi (None, 32, 32, 128)       1280
# ...

# %%
# !git remote add origin https://github.com/VincentH23/ProjetClassificationDechet1.git

# %%
! git add .

# %%
! git remote add origin https://github.com/VincentH23/ProjetClassificationDechet1.git
# Out:
# fatal: remote origin already exists.

# %%
! git branch -M main

# %%
! git push -u origin main
# Out:
# Username for 'https://github.com': ^C

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7b18b6fc-33c1-4d19-8af7-1afafc108f4a' target="_blank">
# <img style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
